# %% [markdown]
# <a href="https://colab.research.google.com/github/layalgt/Reinforcement-Learning-Project/blob/main/With%20Cost/With_cost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**First: Setting things up**

# %%
#Start by cloning the repository
# !git clone https://github.com/andredelft/flock-learning.git
# %cd flock-learning
# Out:
# Cloning into 'flock-learning'...
# remote: Enumerating objects: 3724, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 3724 (delta 110), reused 122 (delta 84), pack-reused 3556 (from 1)
# Receiving objects: 100% (3724/3724), 1.22 GiB | 23.13 MiB/s, done.
# Resolving deltas: 100% (2520/2520), done.
# Updating files: 100% (2257/2257), done.
# /content/flock-learning

# %%
#Installing all needed requirements
# !pip install -r requirements.txt
# Out:
# Collecting matplotlib==3.1.1 (from -r requirements.txt (line 1))
#   Downloading matplotlib-3.1.1.tar.gz (37.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.8/37.8 MB 13.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting numpy==1.17.2 (from -r requirements.txt (line 2))
#   Downloading numpy-1.17.2.zip (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting regex==2020.2.20 (from -r requirements.txt (line 3))
#   Downloading regex-2020.2.20.tar.gz (681 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 681.2/681.2 kB 35.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting scipy==1.3.1 (from -r requirements.txt (line 4))
#   Downloading scipy-1.3.1.tar.gz (23.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 8.8 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Installing build dependencies ... error
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %% [markdown]
# ##**Importing needed packages**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import importlib
import json
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
from collections import Counter
import matplotlib.cm as cm
import os

# %% [markdown]
# I will use the repository to do the following:
#
# *   Set up a field and simulate a run with a given number of birds
# *   Train the birds to learn the best policy

# %% [markdown]
# ##**Running a simulation to train the birds and then see if they learnt the optimal policy**

# %%
#Calling the Field function to generate a simulation of 100 birds
import importlib
import birds    #modified version to include cost is on the github repository
import field    #modified version to include cost is on the github repository
importlib.reload(birds)
importlib.reload(field)
from birds import Birds     #to use the updated class Birds
from field import Field     #to use the updated class Birds

Field(
    numbirds=100,
    sim_length=10000,
    record_data=True,
    record_every=500,          #saves data every 500 steps
    plot = False,              #turns off plotting
    Q_every=1000,              #saves Q-tables every 1000 steps
    comment='Q-learning test'  #uses Q-learning algorithm
)
# Out:
# Record files with tag 20250624-163948 initalized
# Delta = 0.500385611949398
# Recorded up to timestep 0
# Delta = 0.4985108977290047
# Recorded up to timestep 500
# Delta = 0.49748971193415636
# Recorded up to timestep 1000
# Delta = 0.4966758116140832
# Recorded up to timestep 1500
# Delta = 0.4956241426611797
# Recorded up to timestep 2000
# Delta = 0.49479042828837067
# Recorded up to timestep 2500
# Delta = 0.4941761926535589
# Recorded up to timestep 3000
# Delta = 0.4935086114921506
# Recorded up to timestep 3500
# Delta = 0.49291571406797746
# Recorded up to timestep 4000
# Delta = 0.49245084590763605
# Recorded up to timestep 4500
# Delta = 0.4921002895900015
# Recorded up to timestep 5000
# Delta = 0.4917360158512422
# Recorded up to timestep 5500
# Delta = 0.49139003200731596
# Recorded up to timestep 6000
# Delta = 0.49088401158360007
# Recorded up to timestep 6500
# Delta = 0.4905136412132297
# Recorded up to timestep 7000
# Delta = 0.4901036427373876
# Recorded up to timestep 7500
# Delta = 0.48945130315500684
# Recorded up to timestep 8000
# Delta = 0.4889529035208048
# Recorded up to timestep 8500
# Delta = 0.4886846517299192
# Recorded up to timestep 9000
# Delta = 0.4885200426764213
# Recorded up to timestep 9500
# Delta = 0.48807041609510743
# Recorded up to timestep 10000

# %%
### Saving the generated files (can be found in the data folder on the repository) ###
base_dir = '/content/flock-learning/data'
prefix = '20250624-155149'
zip_path = f'/content/{prefix}.zip'

# !cd "{base_dir}" && zip -r "{zip_path}" {prefix}*

from google.colab import files
files.download(zip_path)
# Out:
# updating: 20250624-155149-Delta.npy (deflated 17%)
# updating: 20250624-155149-instincts.json (deflated 87%)
# updating: 20250624-155149-Q/ (stored 0%)
# updating: 20250624-155149-Q/00000000.npy (deflated 6%)
# updating: 20250624-155149-Q/00004000.npy (deflated 6%)
# updating: 20250624-155149-Q/00010000.npy (deflated 6%)
# updating: 20250624-155149-Q/00003000.npy (deflated 6%)
# updating: 20250624-155149-Q/00005000.npy (deflated 6%)
# updating: 20250624-155149-Q/00001000.npy
#
#
# zip error: Interrupted (aborting)

# %%
### Plotting Delta ###
from plot import plot_Delta
plot_Delta('data/20250624-155149-Delta.npy')

plt.xlabel('Time step')
plt.ylabel(r'$\Delta$ (t)')
plt.title('Delta vs Time during the Training Process\nCollision radius = 1000')
plt.show()

# %% [markdown]
# ##**Training for a longer time (from 10000 to 20000)**

# %%
Field(
    numbirds=100,
    sim_length=20000,
    record_data=True,
    record_every=500,
    plot = False,
    Q_every=1000,
    comment='Q-learning test'
)
# Out:
# Record files with tag 20250624-160520 initalized
# Delta = 0.4999481786313062
# Recorded up to timestep 0
# Delta = 0.49652034750800184
# Recorded up to timestep 500
# Delta = 0.49396281054717267
# Recorded up to timestep 1000
# Delta = 0.4921155311690291
# Recorded up to timestep 1500
# Delta = 0.4903688462124676
# Recorded up to timestep 2000
# Delta = 0.4888477366255144
# Recorded up to timestep 2500
# Delta = 0.4875811614083219
# Recorded up to timestep 3000
# Delta = 0.48676421277244325
# Recorded up to timestep 3500
# Delta = 0.4852461515012955
# Recorded up to timestep 4000
# Delta = 0.4842463039170858
# Recorded up to timestep 4500
# Delta = 0.48304221917390644
# Recorded up to timestep 5000
# Delta = 0.4819875019051974
# Recorded up to timestep 5500
# Delta = 0.48094040542600214
# Recorded up to timestep 6000
# Delta = 0.4801021185794848
# Recorded up to timestep 6500
# Delta = 0.4791647614692882
# Recorded up to timestep 7000
# Delta = 0.4784285932022558
# Recorded up to timestep 7500
# Delta = 0.47775643956713915
# Recorded up to timestep 8000
# Delta = 0.4771665904587715
# Recorded up to timestep 8500
# Delta = 0.47656607224508457
# Recorded up to timestep 9000
# Delta = 0.4759853680841335
# Recorded up to timestep 9500
# Delta = 0.47522328913275413
# Recorded up to timestep 10000
# Delta = 0.47431184270690446
# Recorded up to timestep 10500
# Delta = 0.4738926992836458
# Recorded up to timestep 11000
# Delta = 0.473266270385612
# Recorded up to timestep 11500
# Delta = 0.4726566072245085
# Recorded up to timestep 12000
# Delta = 0.4721521109586953
# Recorded up to timestep 12500
# Delta = 0.47176192653558907
# Recorded up to timestep 13000
# Delta = 0.471269623532998
# Recorded up to timestep 13500
# Delta = 0.47077122389879594
# Recorded up to timestep 14000
# Delta = 0.47037799115988416
# Recorded up to timestep 14500
# Delta = 0.470170705685109
# Recorded up to timestep 15000
# Delta = 0.46975461057765583
# Recorded up to timestep 15500
# Delta = 0.46931870141746684
# Recorded up to timestep 16000
# Delta = 0.4688705989940558
# Recorded up to timestep 16500
# Delta = 0.46856576741350403
# Recorded up to timestep 17000
# Delta = 0.4681923487273282
# Recorded up to timestep 17500
# Delta = 0.4677244322511812
# Recorded up to timestep 18000
# Delta = 0.4673494894071026
# Recorded up to timestep 18500
# Delta = 0.4669913122999543
# Recorded up to timestep 19000
# Delta = 0.46645938119189145
# Recorded up to timestep 19500
# Delta = 0.46609815576893765
# Recorded up to timestep 20000

# %%
###Saving the files:
base_dir = '/content/flock-learning/data'
prefix = '20250624-160520'
zip_path = f'/content/{prefix}.zip'

# !cd "{base_dir}" && zip -r "{zip_path}" {prefix}*

from google.colab import files
files.download(zip_path)
# Out:
#   adding: 20250624-160520-Delta.npy (deflated 9%)
#   adding: 20250624-160520-instincts.json (deflated 86%)
#   adding: 20250624-160520-Q/ (stored 0%)
#   adding: 20250624-160520-Q/00000000.npy (deflated 6%)
#   adding: 20250624-160520-Q/00004000.npy (deflated 6%)
#   adding: 20250624-160520-Q/00010000.npy (deflated 6%)
#   adding: 20250624-160520-Q/00013000.npy (deflated 6%)
#   adding: 20250624-160520-Q/00011000.npy (deflated 6%)
#   adding: 20250624-160520-Q/00020000.npy (deflated 5%)
#   adding: 20250624-160520-Q/00014000.npy (deflated 6%)
#   adding: 20250624-160520-Q/00003000.npy (deflated 6%)
#   adding: 20250624-160520-Q/00005000.npy (deflated 6%)
#   adding: 20250624-160520-Q/00001000.npy (deflated 6%)
#   adding: 20250624-160520-Q/00012000.npy (deflated 6%)
#   adding: 20250624-160520-Q/00016000.npy (deflated 5%)
#   adding: 20250624-160520-Q/00008000.npy (deflated 6%)
#   adding: 20250624-160520-Q/00017000.npy (deflated 5%)
#   adding: 20250624-160520-Q/00015000.npy (deflated 6%)
#   adding: 20250624-160520-Q/00019000.npy (deflated 5%)
#   adding: 20250624-160520-Q/00009000.npy (deflated 6%)
#   adding: 20250624-160520-Q/00002000.npy (deflated 6%)
#   adding: 20250624-160520-Q/00018000.npy (deflated 5%)
#   adding: 20250624-160520-Q/00007000.npy (deflated 6%)
#   adding: 20250624-160520-Q/00006000.npy (deflated 6%)
#   adding: 20250624-160520-Q.npy (deflated 5%)
#   adding: 20250624-160520-v.npy (deflated 67%)

# %%
plot_Delta('data/20250624-160520-Delta.npy')

plt.xlabel('Time')
plt.ylabel(r'$\Delta$ (t)')
plt.title('Delta vs Time during the Training Process\nCollision radius = 10')
plt.show()

# %% [markdown]
# ##**Analyzing the learnt Q-tables**
# We will compare the Q-tables at the beginning of the training phase (referred to as initial or with index i) and at the end of the training process (referred to as final or with index f)

# %%
Q_tables_i = np.load('data/20250624-160520-Q/00000000.npy')
Q_tables_f = np.load('data/20250624-160520-Q/00020000.npy')
#print(Q_tables_i.shape, Q_tables_f.shape)

state_indices = np.arange(0, 7000, 1000)  #Since we have over 6000 states, we will generate plots for each 1000th state

fig, axes = plt.subplots(nrows=len(state_indices), ncols=2, figsize=(12, 3 * len(state_indices)))
fig.suptitle("Q-value Distributions (Initial vs Final) at a Given State", fontsize=16)

for idx, state_index in enumerate(state_indices):
    q_i = Q_tables_i[:, state_index, :]
    q_f = Q_tables_f[:, state_index, :]

    q_vicsek_i = q_i[:, 0]
    q_instinct_i = q_i[:, 1]
    q_vicsek_f = q_f[:, 0]
    q_instinct_f = q_f[:, 1]

    bins_i = np.linspace(min(q_vicsek_i.min(), q_instinct_i.min()), max(q_vicsek_i.max(), q_instinct_i.max()), 10)
    centers_i = 0.5 * (bins_i[1:] + bins_i[:-1])
    width_i = (bins_i[1] - bins_i[0]) * 0.4

    bins_f = np.linspace(min(q_vicsek_f.min(), q_instinct_f.min()), max(q_vicsek_f.max(), q_instinct_f.max()), 10)
    centers_f = 0.5 * (bins_f[1:] + bins_f[:-1])
    width_f = (bins_f[1] - bins_f[0]) * 0.4

    ax_i = axes[idx, 0]
    counts_v_i, _ = np.histogram(q_vicsek_i, bins=bins_i)
    counts_i_i, _ = np.histogram(q_instinct_i, bins=bins_i)
    ax_i.bar(centers_i - width_i/2, counts_v_i, width=width_i, label='Vicsek (V)')
    ax_i.bar(centers_i + width_i/2, counts_i_i, width=width_i, label='Instinct (I)')
    ax_i.set_title(f'Initial Q-table - State {state_index}')
    ax_i.set_xlabel('Q-value')
    ax_i.set_ylabel('Number of Birds')
    ax_i.legend()

    ax_f = axes[idx, 1]
    counts_v_f, _ = np.histogram(q_vicsek_f, bins=bins_f)
    counts_i_f, _ = np.histogram(q_instinct_f, bins=bins_f)
    ax_f.bar(centers_f - width_f/2, counts_v_f, width=width_f, label='Vicsek (V)')
    ax_f.bar(centers_f + width_f/2, counts_i_f, width=width_f, label='Instinct (I)')
    ax_f.set_title(f'Final Q-table - State {state_index}')
    ax_f.set_xlabel('Q-value')
    ax_f.set_ylabel('Number of Birds')
    ax_f.legend()

plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.show()

# %%
### Below, we do the same but using the averaged Q-values (averages taken over each state)###

Q_avg_i = np.mean(Q_tables_i, axis=0)
Q_avg_f = np.mean(Q_tables_f, axis=0)
#print(Q_avg_i.shape, Q_avg_f.shape)

state_indices = np.arange(0, 7000, 1000)

n = len(state_indices)
fig, axes = plt.subplots(nrows=n, ncols=2, figsize=(8, 2.5 * n))

for idx, state_index in enumerate(state_indices):
    sns.heatmap(Q_avg_i[state_index].reshape(1, -1),
                cmap='viridis', ax=axes[idx, 0],
                xticklabels=['V', 'I'],
                yticklabels=[f'State {state_index}'],
                cbar=True)
    axes[idx, 0].set_title(f'Initial Average Q-table')


    sns.heatmap(Q_avg_f[state_index].reshape(1, -1),
                cmap='viridis', ax=axes[idx, 1],
                xticklabels=['V', 'I'],
                yticklabels=[f'State {state_index}'],
                cbar=True)
    axes[idx, 1].set_title(f'Final Average Q-table')


fig.suptitle("Average Q-values for Selected States (Initial vs Final)", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.show()

# %% [markdown]
# ##**Varying the learning parameters**
# We define a range of parameter values, and we run a simulation for each value. For every simulation run, the corresponding evolution of $\Delta(t)$ is recorded and plotted.

# %% [markdown]
# ##**Start with the learning parameter: $\alpha$**

# %%
alphas = np.arange(0,1.1,0.1)

for alpha in alphas:
    Field(
        100,
        sim_length= 5000,
        alpha=alpha,
        learning_alg='Q',
        record_data=True,
        plot=False)
# Out:
# Record files with tag 20250625-074759 initalized
# Delta = 0.49925316262764824
# Recorded up to timestep 0
# Delta = 0.49925316262764824
# Recorded up to timestep 500
# Delta = 0.49925316262764824
# Recorded up to timestep 1000
# Delta = 0.49925316262764824
# Recorded up to timestep 1500
# Delta = 0.49925316262764824
# Recorded up to timestep 2000
# Delta = 0.49925316262764824
# Recorded up to timestep 2500
# Delta = 0.49925316262764824
# Recorded up to timestep 3000
# Delta = 0.49925316262764824
# Recorded up to timestep 3500
# Delta = 0.49925316262764824
# Recorded up to timestep 4000
# Delta = 0.49925316262764824
# Recorded up to timestep 4500
# Delta = 0.49925316262764824
# Recorded up to timestep 5000
# Record files with tag 20250625-075205 initalized
# Delta = 0.4997286998933089
# Recorded up to timestep 0
# Delta = 0.4961179698216735
# Recorded up to timestep 500
# Delta = 0.493632068282274
# Recorded up to timestep 1000
# Delta = 0.4916034141137022
# Recorded up to timestep 1500
# Delta = 0.4898552049992379
# Recorded up to timestep 2000
# Delta = 0.4885368084133516
# Recorded up to timestep 2500
# Delta = 0.48743484224965705
# Recorded up to timestep 3000
# Delta = 0.48633135192805976
# Recorded up to timestep 3500
# Delta = 0.48545191281816796
# Recorded up to timestep 4000
# Delta = 0.48478737997256516
# Recorded up to timestep 4500
# Delta = 0.4840877914951989
# Recorded up to timestep 5000
# Record files with tag 20250625-075610 initalized
# Delta = 0.4993842402072855
# Recorded up to timestep 0
# Delta = 0.4954320987654321
# Recorded up to timestep 500
# Delta = 0.4924965706447188
# Recorded up to timestep 1000
# Delta = 0.4905944215820759
# Recorded up to timestep 1500
# Delta = 0.4886846517299192
# Recorded up to timestep 2000
# Delta = 0.48698369151044046
# Recorded up to timestep 2500
# Delta = 0.48595793324188385
# Recorded up to timestep 3000
# Delta = 0.4847858558146624
# Recorded up to timestep 3500
# Delta = 0.48367322054564854
# Recorded up to timestep 4000
# Delta = 0.4829111415942692
# Recorded up to timestep 4500
# Delta = 0.48212772443225116
# Recorded up to timestep 5000
# Record files with tag 20250625-080011 initalized
# Delta = 0.5003490321597317
# Recorded up to timestep 0
# Delta = 0.49635421429660115
# Recorded up to timestep 500
# Delta = 0.4937600975461058
# Recorded up to timestep 1000
# Delta = 0.49171772595640906
# Recorded up to timestep 1500
# Delta = 0.4897622313671696
# Recorded up to timestep 2000
# Delta = 0.4883127572016461
# Recorded up to timestep 2500
# Delta = 0.487081237616217
# Recorded up to timestep 3000
# Delta = 0.48605090687395214
# Recorded up to timestep 3500
# Delta = 0.4852659655540314
# Recorded up to timestep 4000
# Delta = 0.48413808870598996
# Recorded up to timestep 4500
# Delta = 0.4830650815424478
# Recorded up to timestep 5000
# Record files with tag 20250625-080412 initalized
# Delta = 0.49881725346745925
# Recorded up to timestep 0
# Delta = 0.49558299039780523
# Recorded up to timestep 500
# Delta = 0.4935558603871361
# Recorded up to timestep 1000
# Delta = 0.49170400853528423
# Recorded up to timestep 1500
# Delta = 0.4905426002133821
# Recorded up to timestep 2000
# Delta = 0.4894055784179241
# Recorded up to timestep 2500
# Delta = 0.48806279530559366
# Recorded up to timestep 3000
# Delta = 0.4870233196159122
# Recorded up to timestep 3500
# Delta = 0.4858222831885383
# Recorded up to timestep 4000
# Delta = 0.4849260783417162
# Recorded up to timestep 4500
# Delta = 0.4839551897576589
# Recorded up to timestep 5000
# Record files with tag 20250625-080814 initalized
# Delta = 0.5010531931108063
# Recorded up to timestep 0
# Delta = 0.49696692577351015
# Recorded up to timestep 500
# Delta = 0.4941182746532541
# Recorded up to timestep 1000
# Delta = 0.4918122237463801
# Recorded up to timestep 1500
# Delta = 0.489873494894071
# Recorded up to timestep 2000
# Delta = 0.48811156835848196
# Recorded up to timestep 2500
# Delta = 0.4862155159274501
# Recorded up to timestep 3000
# Delta = 0.48507849413199206
# Recorded up to timestep 3500
# Delta = 0.4838972717573541
# Recorded up to timestep 4000
# Delta = 0.48293705227861605
# Recorded up to timestep 4500
# Delta = 0.4817604023776863
# Recorded up to timestep 5000
# Record files with tag 20250625-081218 initalized
# Delta = 0.4993339429964944
# Recorded up to timestep 0
# Delta = 0.49567748818777624
# Recorded up to timestep 500
# Delta = 0.4937235177564396
# Recorded up to timestep 1000
# Delta = 0.4918945282731291
# Recorded up to timestep 1500
# Delta = 0.48994970278920896
# Recorded up to timestep 2000
# Delta = 0.4881268099375095
# Recorded up to timestep 2500
# Delta = 0.48696235329980186
# Recorded up to timestep 3000
# Delta = 0.4861118731900625
# Recorded up to timestep 3500
# Delta = 0.48509373571101966
# Recorded up to timestep 4000
# Delta = 0.4839155616521872
# Recorded up to timestep 4500
# Delta = 0.4832174973327237
# Recorded up to timestep 5000
# Record files with tag 20250625-081616 initalized
# Delta = 0.4991525682060661
# Recorded up to timestep 0
# Delta = 0.49506477671086724
# Recorded up to timestep 500
# Delta = 0.49270385611949397
# Recorded up to timestep 1000
# Delta = 0.49069196768785245
# Recorded up to timestep 1500
# Delta = 0.4890656912056089
# Recorded up to timestep 2000
# Delta = 0.4875140984606005
# Recorded up to timestep 2500
# Delta = 0.4860585276634659
# Recorded up to timestep 3000
# Delta = 0.4846928821825941
# Recorded up to timestep 3500
# Delta = 0.48358634354519126
# Recorded up to timestep 4000
# Delta = 0.48216582837982014
# Recorded up to timestep 4500
# Delta = 0.4811111111111111
# Recorded up to timestep 5000
# Record files with tag 20250625-082008 initalized
# Delta = 0.49998780673677795
# Recorded up to timestep 0
# Delta = 0.4963770766651425
# Recorded up to timestep 500
# Delta = 0.4933866788599299
# Recorded up to timestep 1000
# Delta = 0.49160798658741045
# Recorded up to timestep 1500
# Delta = 0.4898719707361683
# Recorded up to timestep 2000
# Delta = 0.4889361377838744
# Recorded up to timestep 2500
# Delta = 0.48806279530559366
# Recorded up to timestep 3000
# Delta = 0.4869974089315653
# Recorded up to timestep 3500
# Delta = 0.4864913885078494
# Recorded up to timestep 4000
# Delta = 0.48549306508154244
# Recorded up to timestep 4500
# Delta = 0.48466849565615
# Recorded up to timestep 5000
# Record files with tag 20250625-082359 initalized
# Delta = 0.4999969516841945
# Recorded up to timestep 0
# Delta = 0.4966346593507087
# Recorded up to timestep 500
# Delta = 0.4941015089163237
# Recorded up to timestep 1000
# Delta = 0.4918838591678098
# Recorded up to timestep 1500
# Delta = 0.490391708581009
# Recorded up to timestep 2000
# Delta = 0.48908855357415026
# Recorded up to timestep 2500
# Delta = 0.4877853985672916
# Recorded up to timestep 3000
# Delta = 0.4866163694558756
# Recorded up to timestep 3500
# Delta = 0.485679012345679
# Recorded up to timestep 4000
# Delta = 0.4844215820759031
# Recorded up to timestep 4500
# Delta = 0.4834598384392623
# Recorded up to timestep 5000
# Record files with tag 20250625-082751 initalized
# Delta = 0.5006081390032008
# Recorded up to timestep 0
# Delta = 0.496544734034446
# Recorded up to timestep 500
# Delta = 0.4931611034903216
# Recorded up to timestep 1000
# Delta = 0.4906797744246304
# Recorded up to timestep 1500
# Delta = 0.48831428135954885
# Recorded up to timestep 2000
# Delta = 0.4866346593507087
# Recorded up to timestep 2500
# Delta = 0.4848742569730224
# Recorded up to timestep 3000
# Delta = 0.483272367017223
# Recorded up to timestep 3500
# Delta = 0.482008840115836
# Recorded up to timestep 4000
# Delta = 0.48064471879286697
# Recorded up to timestep 4500
# Delta = 0.47935832952293855
# Recorded up to timestep 5000

# %%
#NOTE: I know there is for sure a more efficient way to do the below, but despite all my attempts to modify
#the original codebase to save the files in folder for easier access, I didn't manage to, so I had to do it as per below

f0  = np.load("data/20250625-074759-Delta.npy")
f01 = np.load("data/20250625-075205-Delta.npy")
f02 = np.load("data/20250625-075610-Delta.npy")
f03 = np.load("data/20250625-080011-Delta.npy")
f04 = np.load("data/20250625-080412-Delta.npy")
f05 = np.load("data/20250625-080814-Delta.npy")
f06 = np.load("data/20250625-081218-Delta.npy")
f07 = np.load("data/20250625-081616-Delta.npy")
f08 = np.load("data/20250625-082008-Delta.npy")
f09 = np.load("data/20250625-082359-Delta.npy")
f1  = np.load("data/20250625-082751-Delta.npy")

#Store in dictionary to ease plotting later on
delta_dict = {
    "f0": f0, "f01": f01, "f02": f02, "f03": f03, "f04": f04,
    "f05": f05, "f06": f06, "f07": f07, "f08": f08, "f09": f09, "f1": f1}

# %%
delta_list = [f0, f01, f02, f03, f04, f05, f06, f07, f08, f09, f1]
alphas = [round(i * 0.1, 1) for i in range(len(delta_list))]

#Each Delta is recorded every 500 steps up to 5000
timesteps = np.arange(0, len(delta_list[0]) * 500, 500)

#Defining colormap
cmap = cm.get_cmap('tab10', len(delta_list))


plt.figure(figsize=(10, 6))
for idx, (delta, alpha) in enumerate(zip(delta_list, alphas)):
    plt.plot(timesteps, delta, label=fr'$\alpha$ = {alpha}', color=cmap(idx))

plt.xlabel("Time")
plt.ylabel(r'$\Delta(t)$')
plt.title(r'$\Delta$ vs Time for Different $\alpha$ Values')
plt.legend(title=r'Learning Rate ($\alpha$)')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-10-4047685406.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab10', len(delta_list))  # or 'Set1' for vivid contrast

# %% [markdown]
# ##**For the exploration rate: $\epsilon$**

# %%
epsilon = np.arange(0,1.1,0.1)

for e in epsilon:
    print(f"Running simulation with epsilon = {e}")   #added to track progress
    Field(
        100,
        sim_length=8000,
        epsilon = e,
        learning_alg='Q',
        record_data=True,
        plot=False    )
# Out:
# Running simulation with epsilon = 0.0
# Record files with tag 20250625-084457 initalized
# Delta = 0.500321597317482
# Recorded up to timestep 0
# Delta = 0.4974485596707819
# Recorded up to timestep 500
# Delta = 0.4957689376619418
# Recorded up to timestep 1000
# Delta = 0.4953223593964335
# Recorded up to timestep 1500
# Delta = 0.49519890260631
# Recorded up to timestep 2000
# Delta = 0.49504648681603414
# Recorded up to timestep 2500
# Delta = 0.49483920134125897
# Recorded up to timestep 3000
# Delta = 0.493840877914952
# Recorded up to timestep 3500
# Delta = 0.4927358634354519
# Recorded up to timestep 4000
# Delta = 0.49216278006401465
# Recorded up to timestep 4500
# Delta = 0.4917604023776863
# Recorded up to timestep 5000
# Delta = 0.49117360158512424
# Recorded up to timestep 5500
# Delta = 0.4909144947416552
# Recorded up to timestep 6000
# Delta = 0.4904465782655083
# Recorded up to timestep 6500
# Delta = 0.4901204084743179
# Recorded up to timestep 7000
# Delta = 0.4900624904740131
# Recorded up to timestep 7500
# Delta = 0.48986282578875173
# Recorded up to timestep 8000
# Running simulation with epsilon = 0.1
# Record files with tag 20250625-085111 initalized
# Delta = 0.500568510897729
# Recorded up to timestep 0
# Delta = 0.4977686328303612
# Recorded up to timestep 500
# Delta = 0.49513793629019964
# Recorded up to timestep 1000
# Delta = 0.4934537418076513
# Recorded up to timestep 1500
# Delta = 0.4918609967992684
# Recorded up to timestep 2000
# Delta = 0.4911263526901387
# Recorded up to timestep 2500
# Delta = 0.4901082152110959
# Recorded up to timestep 3000
# Delta = 0.4894604481024234
# Recorded up to timestep 3500
# Delta = 0.4884819387288523
# Recorded up to timestep 4000
# Delta = 0.487814357567444
# Recorded up to timestep 4500
# Delta = 0.48703703703703705
# Recorded up to timestep 5000
# Delta = 0.486380124980948
# Recorded up to timestep 5500
# Delta = 0.48569577808260933
# Recorded up to timestep 6000
# Delta = 0.48516841944825484
# Recorded up to timestep 6500
# Delta = 0.4847111720774272
# Recorded up to timestep 7000
# Delta = 0.48439262307575065
# Recorded up to timestep 7500
# Delta = 0.48396281054717266
# Recorded up to timestep 8000
# Running simulation with epsilon = 0.2
# Record files with tag 20250625-085722 initalized
# Delta = 0.4993156531016613
# Recorded up to timestep 0
# Delta = 0.4960615759792715
# Recorded up to timestep 500
# Delta = 0.49380124980948026
# Recorded up to timestep 1000
# Delta = 0.4917360158512422
# Recorded up to timestep 1500
# Delta = 0.4900731595793324
# Recorded up to timestep 2000
# Delta = 0.48824417009602195
# Recorded up to timestep 2500
# Delta = 0.4867748818777625
# Recorded up to timestep 3000
# Delta = 0.48581771071483004
# Recorded up to timestep 3500
# Delta = 0.4849077884468831
# Recorded up to timestep 4000
# Delta = 0.48410455723212925
# Recorded up to timestep 4500
# Delta = 0.48351165980795613
# Recorded up to timestep 5000
# Delta = 0.48230605090687395
# Recorded up to timestep 5500
# Delta = 0.48147843316567596
# Recorded up to timestep 6000
# Delta = 0.48070263679317177
# Recorded up to timestep 6500
# Delta = 0.48022100289590003
# Recorded up to timestep 7000
# Delta = 0.47960829141899103
# Recorded up to timestep 7500
# Delta = 0.4791860996799268
# Recorded up to timestep 8000
# Running simulation with epsilon = 0.30000000000000004
# Record files with tag 20250625-090339 initalized
# Delta = 0.50039780521262
# Recorded up to timestep 0
# Delta = 0.49711324493217496
# Recorded up to timestep 500
# Delta = 0.49466849565614995
# Recorded up to timestep 1000
# Delta = 0.49203932327389116
# Recorded up to timestep 1500
# Delta = 0.4906675811614083
# Recorded up to timestep 2000
# Delta = 0.4895016003657979
# Recorded up to timestep 2500
# Delta = 0.48822588020118884
# Recorded up to timestep 3000
# Delta = 0.48705075445816187
# Recorded up to timestep 3500
# Delta = 0.4859350708733425
# Recorded up to timestep 4000
# Delta = 0.48497180307879895
# Recorded up to timestep 4500
# Delta = 0.4839841487578113
# Recorded up to timestep 5000
# Delta = 0.4828760859625057
# Recorded up to timestep 5500
# Delta = 0.48191434232586494
# Recorded up to timestep 6000
# Delta = 0.4810775796372504
# Recorded up to timestep 6500
# Delta = 0.4803398872123152
# Recorded up to timestep 7000
# Delta = 0.479614388050602
# Recorded up to timestep 7500
# Delta = 0.478951379362902
# Recorded up to timestep 8000
# Running simulation with epsilon = 0.4
# Record files with tag 20250625-090952 initalized
# Delta = 0.5005273586343545
# Recorded up to timestep 0
# Delta = 0.49753848498704467
# Recorded up to timestep 500
# Delta = 0.4946227709190672
# Recorded up to timestep 1000
# Delta = 0.4926230757506478
# Recorded up to timestep 1500
# Delta = 0.4907300716354214
# Recorded up to timestep 2000
# Delta = 0.4892943148910227
# Recorded up to timestep 2500
# Delta = 0.48743331809175433
# Recorded up to timestep 3000
# Delta = 0.4859472641365645
# Recorded up to timestep 3500
# Delta = 0.48478433165675966
# Recorded up to timestep 4000
# Delta = 0.483758573388203
# Recorded up to timestep 4500
# Delta = 0.48281054717268707
# Recorded up to timestep 5000
# Delta = 0.48212162780064016
# Recorded up to timestep 5500
# Delta = 0.4812330437433318
# Recorded up to timestep 6000
# Delta = 0.48043438500228625
# Recorded up to timestep 6500
# Delta = 0.47952903520804757
# Recorded up to timestep 7000
# Delta = 0.4782792257277854
# Recorded up to timestep 7500
# Delta = 0.47770004572473707
# Recorded up to timestep 8000
# Running simulation with epsilon = 0.5
# Record files with tag 20250625-091602 initalized
# Delta = 0.5006965401615607
# Recorded up to timestep 0
# Delta = 0.4971940253010212
# Recorded up to timestep 500
# Delta = 0.49502362444749276
# Recorded up to timestep 1000
# Delta = 0.49326169791190366
# Recorded up to timestep 1500
# Delta = 0.4916399939033684
# Recorded up to timestep 2000
# Delta = 0.49055936595031246
# Recorded up to timestep 2500
# Delta = 0.4893324188385917
# Recorded up to timestep 3000
# Delta = 0.48849870446578264
# Recorded up to timestep 3500
# Delta = 0.4877137631458619
# Recorded up to timestep 4000
# Delta = 0.4868663313519281
# Recorded up to timestep 4500
# Delta = 0.4863846974546563
# Recorded up to timestep 5000
# Delta = 0.48570644718792866
# Recorded up to timestep 5500
# Delta = 0.4851333638164914
# Recorded up to timestep 6000
# Delta = 0.4845983843926231
# Recorded up to timestep 6500
# Delta = 0.4839887212315196
# Recorded up to timestep 7000
# Delta = 0.4833744855967078
# Recorded up to timestep 7500
# Delta = 0.48265355890870293
# Recorded up to timestep 8000
# Running simulation with epsilon = 0.6000000000000001
# Record files with tag 20250625-092211 initalized
# Delta = 0.500214906264289
# Recorded up to timestep 0
# Delta = 0.49727328151196465
# Recorded up to timestep 500
# Delta = 0.49506020423715896
# Recorded up to timestep 1000
# Delta = 0.4932022557536961
# Recorded up to timestep 1500
# Delta = 0.49103642737387593
# Recorded up to timestep 2000
# Delta = 0.4894863587867703
# Recorded up to timestep 2500
# Delta = 0.48821825941167507
# Recorded up to timestep 3000
# Delta = 0.4871056241426612
# Recorded up to timestep 3500
# Delta = 0.4858024691358025
# Recorded up to timestep 4000
# Delta = 0.484939795762841
# Recorded up to timestep 4500
# Delta = 0.48401463191586647
# Recorded up to timestep 5000
# Delta = 0.48315195854290505
# Recorded up to timestep 5500
# Delta = 0.4822999542752629
# Recorded up to timestep 6000
# Delta = 0.4816826703246456
# Recorded up to timestep 6500
# Delta = 0.48087029416247523
# Recorded up to timestep 7000
# Delta = 0.4799237921048621
# Recorded up to timestep 7500
# Delta = 0.4793674744703551
# Recorded up to timestep 8000
# Running simulation with epsilon = 0.7000000000000001
# Record files with tag 20250625-092816 initalized
# Delta = 0.5001798506325256
# Recorded up to timestep 0
# Delta = 0.49691358024691357
# Recorded up to timestep 500
# Delta = 0.4943347050754458
# Recorded up to timestep 1000
# Delta = 0.4917786922725194
# Recorded up to timestep 1500
# Delta = 0.48967992684042067
# Recorded up to timestep 2000
# Delta = 0.48771985977747295
# Recorded up to timestep 2500
# Delta = 0.48630239292790733
# Recorded up to timestep 3000
# Delta = 0.48522328913275414
# Recorded up to timestep 3500
# Delta = 0.4842021033379058
# Recorded up to timestep 4000
# Delta = 0.48309556470050297
# Recorded up to timestep 4500
# Delta = 0.482350251486054
# Recorded up to timestep 5000
# Delta = 0.48124523700655386
# Recorded up to timestep 5500
# Delta = 0.480518213686938
# Recorded up to timestep 6000
# Delta = 0.4796753543667124
# Recorded up to timestep 6500
# Delta = 0.4790108215211096
# Recorded up to timestep 7000
# Delta = 0.47833257125438194
# Recorded up to timestep 7500
# Delta = 0.4779606767261088
# Recorded up to timestep 8000
# Running simulation with epsilon = 0.8
# Record files with tag 20250625-093432 initalized
# Delta = 0.4984682213077275
# Recorded up to timestep 0
# Delta = 0.4956576741350404
# Recorded up to timestep 500
# Delta = 0.4933302850175278
# Recorded up to timestep 1000
# Delta = 0.491351928059747
# Recorded up to timestep 1500
# Delta = 0.4898003353147386
# Recorded up to timestep 2000
# Delta = 0.4883219021490626
# Recorded up to timestep 2500
# Delta = 0.487030940405426
# Recorded up to timestep 3000
# Delta = 0.4858420972412742
# Recorded up to timestep 3500
# Delta = 0.4848346288675507
# Recorded up to timestep 4000
# Delta = 0.4839887212315196
# Recorded up to timestep 4500
# Delta = 0.48301021185794846
# Recorded up to timestep 5000
# Delta = 0.4820438957475994
# Recorded up to timestep 5500
# Delta = 0.48070263679317177
# Recorded up to timestep 6000
# Delta = 0.47964639536655995
# Recorded up to timestep 6500
# Delta = 0.4786785550983082
# Recorded up to timestep 7000
# Delta = 0.47811156835848195
# Recorded up to timestep 7500
# Delta = 0.4775704923030026
# Recorded up to timestep 8000
# Running simulation with epsilon = 0.9
# Record files with tag 20250625-094041 initalized
# Delta = 0.5004923030025911
# Recorded up to timestep 0
# Delta = 0.4981999695168419
# Recorded up to timestep 500
# Delta = 0.495938119189148
# Recorded up to timestep 1000
# Delta = 0.49449169333942994
# Recorded up to timestep 1500
# Delta = 0.4926916628562719
# Recorded up to timestep 2000
# Delta = 0.49103185490016765
# Recorded up to timestep 2500
# Delta = 0.48976985215668345
# Recorded up to timestep 3000
# Delta = 0.48866026520347505
# Recorded up to timestep 3500
# Delta = 0.4877488187776254
# Recorded up to timestep 4000
# Delta = 0.486898338667886
# Recorded up to timestep 4500
# Delta = 0.48606157597927147
# Recorded up to timestep 5000
# Delta = 0.4852095717116293
# Recorded up to timestep 5500
# Delta = 0.4842584971803079
# Recorded up to timestep 6000
# Delta = 0.48363968907178784
# Recorded up to timestep 6500
# Delta = 0.48300411522633746
# Recorded up to timestep 7000
# Delta = 0.4824371284865112
# Recorded up to timestep 7500
# Delta = 0.4817390641670477
# Recorded up to timestep 8000
# Running simulation with epsilon = 1.0
# Record files with tag 20250625-094649 initalized
# Delta = 0.4999786617893614
# Recorded up to timestep 0
# Delta = 0.4972702331961591
# Recorded up to timestep 500
# Delta = 0.49565157750342936
# Recorded up to timestep 1000
# Delta = 0.49416399939033684
# Recorded up to timestep 1500
# Delta = 0.4927693949093126
# Recorded up to timestep 2000
# Delta = 0.4909297363206828
# Recorded up to timestep 2500
# Delta = 0.4898079561042524
# Recorded up to timestep 3000
# Delta = 0.4886968449931413
# Recorded up to timestep 3500
# Delta = 0.48746532540771226
# Recorded up to timestep 4000
# Delta = 0.4864898643499467
# Recorded up to timestep 4500
# Delta = 0.48566986739826246
# Recorded up to timestep 5000
# Delta = 0.48513488797439414
# Recorded up to timestep 5500
# Delta = 0.4845115073921658
# Recorded up to timestep 6000
# Delta = 0.4837890565462582
# Recorded up to timestep 6500
# Delta = 0.4827297668038409
# Recorded up to timestep 7000
# Delta = 0.48188538332571257
# Recorded up to timestep 7500
# Delta = 0.48119036732205456
# Recorded up to timestep 8000

# %%
f0  = np.load("data/20250625-084457-Delta.npy")
f01 = np.load("data/20250625-085111-Delta.npy")
f02 = np.load("data/20250625-085722-Delta.npy")
f03 = np.load("data/20250625-090339-Delta.npy")
f04 = np.load("data/20250625-090952-Delta.npy")
f05 = np.load("data/20250625-091602-Delta.npy")
f06 = np.load("data/20250625-092211-Delta.npy")
f07 = np.load("data/20250625-092816-Delta.npy")
f08 = np.load("data/20250625-093432-Delta.npy")
f09 = np.load("data/20250625-094041-Delta.npy")
f1  = np.load("data/20250625-094649-Delta.npy")

delta_dict = {
    "f0": f0, "f01": f01, "f02": f02, "f03": f03, "f04": f04,
    "f05": f05, "f06": f06, "f07": f07, "f08": f08, "f09": f09, "f1": f1}

# %%
delta_list = [f0, f01, f02, f03, f04, f05, f06, f07, f08, f09, f1]
e = [round(i * 0.1, 1) for i in range(len(delta_list))]

timesteps = np.arange(0, len(delta_list[0]) * 500, 500)

cmap = cm.get_cmap('tab10', len(delta_list))

plt.figure(figsize=(10, 6))
for idx, (delta, eps) in enumerate(zip(delta_list, e)):
    plt.plot(timesteps, delta, label= fr'$\epsilon$ = {eps}', color=cmap(idx))

plt.title('$\Delta$ vs Time for Different $\epsilon$ values')
plt.xlabel('Time')
plt.ylabel(r'$\Delta(t)$')
plt.legend(title=r'Exploration Rate ($\epsilon$)')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-14-506817374.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab10', len(delta_list))  # or 'Set1' for vivid contrast

# %% [markdown]
# ##**Looking at the Discount Factor: $\gamma$**

# %%
gamma = np.arange(0,1,0.1)

for g in gamma:
    print(f"Running simulation with gamma = {g}")
    Field(
        100,
        sim_length=5000,
        gamma = g,
        learning_alg='Q',
        record_data=True,
        plot=False )
# Out:
# Running simulation with gamma = 0.0
# Record files with tag 20250625-095945 initalized
# Delta = 0.5007041609510745
# Recorded up to timestep 0
# Delta = 0.49739978661789364
# Recorded up to timestep 500
# Delta = 0.4948940710257583
# Recorded up to timestep 1000
# Delta = 0.4929843011736016
# Recorded up to timestep 1500
# Delta = 0.4915363511659808
# Recorded up to timestep 2000
# Delta = 0.4903871361073007
# Recorded up to timestep 2500
# Delta = 0.4892653558908703
# Recorded up to timestep 3000
# Delta = 0.48852918762383785
# Recorded up to timestep 3500
# Delta = 0.4875522024081695
# Recorded up to timestep 4000
# Delta = 0.4867809785093736
# Recorded up to timestep 4500
# Delta = 0.48599146471574456
# Recorded up to timestep 5000
# Running simulation with gamma = 0.1
# Record files with tag 20250625-100347 initalized
# Delta = 0.4993339429964944
# Recorded up to timestep 0
# Delta = 0.49644718792866943
# Recorded up to timestep 500
# Delta = 0.4944352994970279
# Recorded up to timestep 1000
# Delta = 0.4927495808565767
# Recorded up to timestep 1500
# Delta = 0.4913808870598994
# Recorded up to timestep 2000
# Delta = 0.49014631915866486
# Recorded up to timestep 2500
# Delta = 0.4888766956256668
# Recorded up to timestep 3000
# Delta = 0.48795153177869227
# Recorded up to timestep 3500
# Delta = 0.4871178174058832
# Recorded up to timestep 4000
# Delta = 0.4864898643499467
# Recorded up to timestep 4500
# Delta = 0.48574455113549764
# Recorded up to timestep 5000
# Running simulation with gamma = 0.2
# Record files with tag 20250625-100748 initalized
# Delta = 0.49928821825941166
# Recorded up to timestep 0
# Delta = 0.496064624295077
# Recorded up to timestep 500
# Delta = 0.49383782959914646
# Recorded up to timestep 1000
# Delta = 0.49202560585276633
# Recorded up to timestep 1500
# Delta = 0.48991617131534826
# Recorded up to timestep 2000
# Delta = 0.48820454199055024
# Recorded up to timestep 2500
# Delta = 0.48689529035208046
# Recorded up to timestep 3000
# Delta = 0.48574455113549764
# Recorded up to timestep 3500
# Delta = 0.484674592287761
# Recorded up to timestep 4000
# Delta = 0.4836473098613016
# Recorded up to timestep 4500
# Delta = 0.4826566072245085
# Recorded up to timestep 5000
# Running simulation with gamma = 0.30000000000000004
# Record files with tag 20250625-101151 initalized
# Delta = 0.5002606310013717
# Recorded up to timestep 0
# Delta = 0.49775643956713916
# Recorded up to timestep 500
# Delta = 0.4954061880810852
# Recorded up to timestep 1000
# Delta = 0.4935771985977747
# Recorded up to timestep 1500
# Delta = 0.4919417771681146
# Recorded up to timestep 2000
# Delta = 0.49058222831885384
# Recorded up to timestep 2500
# Delta = 0.489387288523091
# Recorded up to timestep 3000
# Delta = 0.48851242188690747
# Recorded up to timestep 3500
# Delta = 0.48768327998780675
# Recorded up to timestep 4000
# Delta = 0.48691510440481633
# Recorded up to timestep 4500
# Delta = 0.48600670629477216
# Recorded up to timestep 5000
# Running simulation with gamma = 0.4
# Record files with tag 20250625-101554 initalized
# Delta = 0.5009739368998628
# Recorded up to timestep 0
# Delta = 0.49785246151501295
# Recorded up to timestep 500
# Delta = 0.49495503734186863
# Recorded up to timestep 1000
# Delta = 0.4928044505410761
# Recorded up to timestep 1500
# Delta = 0.4909708885840573
# Recorded up to timestep 2000
# Delta = 0.4893324188385917
# Recorded up to timestep 2500
# Delta = 0.48791800030483157
# Recorded up to timestep 3000
# Delta = 0.4865996037189453
# Recorded up to timestep 3500
# Delta = 0.4853878981862521
# Recorded up to timestep 4000
# Delta = 0.484365188233501
# Recorded up to timestep 4500
# Delta = 0.4835421429660113
# Recorded up to timestep 5000
# Running simulation with gamma = 0.5
# Record files with tag 20250625-101958 initalized
# Delta = 0.49964639536655997
# Recorded up to timestep 0
# Delta = 0.4960829141899101
# Recorded up to timestep 500
# Delta = 0.4936503581771072
# Recorded up to timestep 1000
# Delta = 0.4912772443225118
# Recorded up to timestep 1500
# Delta = 0.4894939795762841
# Recorded up to timestep 2000
# Delta = 0.48820454199055024
# Recorded up to timestep 2500
# Delta = 0.4871269623532998
# Recorded up to timestep 3000
# Delta = 0.4858420972412742
# Recorded up to timestep 3500
# Delta = 0.4846913580246914
# Recorded up to timestep 4000
# Delta = 0.4838058222831885
# Recorded up to timestep 4500
# Delta = 0.4830894680688919
# Recorded up to timestep 5000
# Running simulation with gamma = 0.6000000000000001
# Record files with tag 20250625-102359 initalized
# Delta = 0.5001478433165676
# Recorded up to timestep 0
# Delta = 0.4966133211400701
# Recorded up to timestep 500
# Delta = 0.4937372351775644
# Recorded up to timestep 1000
# Delta = 0.4917253467459229
# Recorded up to timestep 1500
# Delta = 0.4899451303155007
# Recorded up to timestep 2000
# Delta = 0.4885749123609206
# Recorded up to timestep 2500
# Delta = 0.4875034293552812
# Recorded up to timestep 3000
# Delta = 0.4864929126657522
# Recorded up to timestep 3500
# Delta = 0.48541685718640454
# Recorded up to timestep 4000
# Delta = 0.4844932174973327
# Recorded up to timestep 4500
# Delta = 0.48368998628257887
# Recorded up to timestep 5000
# Running simulation with gamma = 0.7000000000000001
# Record files with tag 20250625-102802 initalized
# Delta = 0.5003795153177869
# Recorded up to timestep 0
# Delta = 0.4974409388812681
# Recorded up to timestep 500
# Delta = 0.49549611339734795
# Recorded up to timestep 1000
# Delta = 0.4935009907026368
# Recorded up to timestep 1500
# Delta = 0.49207590306355736
# Recorded up to timestep 2000
# Delta = 0.4906477671086725
# Recorded up to timestep 2500
# Delta = 0.48934156378600824
# Recorded up to timestep 3000
# Delta = 0.4879942081999695
# Recorded up to timestep 3500
# Delta = 0.4865767413504039
# Recorded up to timestep 4000
# Delta = 0.485843621399177
# Recorded up to timestep 4500
# Delta = 0.48519890260631
# Recorded up to timestep 5000
# Running simulation with gamma = 0.8
# Record files with tag 20250625-103203 initalized
# Delta = 0.5001798506325256
# Recorded up to timestep 0
# Delta = 0.49714372809023016
# Recorded up to timestep 500
# Delta = 0.4949260783417162
# Recorded up to timestep 1000
# Delta = 0.4929675354366712
# Recorded up to timestep 1500
# Delta = 0.49138698369151046
# Recorded up to timestep 2000
# Delta = 0.49013412589544275
# Recorded up to timestep 2500
# Delta = 0.48931108062795303
# Recorded up to timestep 3000
# Delta = 0.48797744246303915
# Recorded up to timestep 3500
# Delta = 0.4866666666666667
# Recorded up to timestep 4000
# Delta = 0.48581008992531627
# Recorded up to timestep 4500
# Delta = 0.4851181222374638
# Recorded up to timestep 5000
# Running simulation with gamma = 0.9
# Record files with tag 20250625-103607 initalized
# Delta = 0.4993202255753696
# Recorded up to timestep 0
# Delta = 0.4965584514555708
# Recorded up to timestep 500
# Delta = 0.49410455723212926
# Recorded up to timestep 1000
# Delta = 0.49210638622161257
# Recorded up to timestep 1500
# Delta = 0.49056698673982624
# Recorded up to timestep 2000
# Delta = 0.4888812680993751
# Recorded up to timestep 2500
# Delta = 0.4877732053040695
# Recorded up to timestep 3000
# Delta = 0.4865599756134736
# Recorded up to timestep 3500
# Delta = 0.48581161408321905
# Recorded up to timestep 4000
# Delta = 0.4847934766041762
# Recorded up to timestep 4500
# Delta = 0.48401463191586647
# Recorded up to timestep 5000

# %%
f0  = np.load("data/20250625-095945-Delta.npy")
f01 = np.load("data/20250625-100347-Delta.npy")
f02 = np.load("data/20250625-100748-Delta.npy")
f03 = np.load("data/20250625-101151-Delta.npy")
f04 = np.load("data/20250625-101554-Delta.npy")
f05 = np.load("data/20250625-101958-Delta.npy")
f06 = np.load("data/20250625-102359-Delta.npy")
f07 = np.load("data/20250625-102802-Delta.npy")
f08 = np.load("data/20250625-103203-Delta.npy")
f09 = np.load("data/20250625-103607-Delta.npy")

delta_dict = {
    "f0": f0, "f01": f01, "f02": f02, "f03": f03, "f04": f04,
    "f05": f05, "f06": f06, "f07": f07, "f08": f08, "f09": f09}

# %%
)delta_list = [f0, f01, f02, f03, f04, f05, f06, f07, f08, f09]
gammas = [round(i * 0.1, 1) for i in range(len(delta_list))]

timesteps = np.arange(0, len(delta_list[0]) * 500, 500)

cmap = cm.get_cmap('tab10', len(delta_list))


plt.figure(figsize=(10, 6))
for idx, (delta, gamma) in enumerate(zip(delta_list, gammas)):
    plt.plot(timesteps, delta, label=fr'$\gamma$ = {gamma}', color=cmap(idx))

plt.xlabel("Time")
plt.ylabel(r'$\Delta(t)$')
plt.title(r'$\Delta$ vs Time for Different $\gamma$ Values')
plt.legend(title=r'Discount Factor ($\gamma$)')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-17-3316535532.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab10', len(delta_list))  # or 'Set1' for vivid contrast
